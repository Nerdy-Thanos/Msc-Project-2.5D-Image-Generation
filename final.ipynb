# %%
from torchvision.utils import make_grid
import os
from PIL import Image

# %%
os.getcwd()
# Out:
# '/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation'

# %%
ls
# Out:
# DCGan/             final.ipynb        infinite/          right/
# Projected-FastGan/ gan/               landscape/
# README.md          holopix50k-master/ left/
# demo/              img_grid.py        mono_depth_estim/

# %%
leftimg_path = "right/data/"
imgs = []
files = os.listdir(leftimg_path)

for file in files:
    img = Image.open(file)
    imgs.append(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [20], in <cell line: 5>()
#       3 files = os.listdir(leftimg_path)
#       5 for file in files:
# ----> 6     img = Image.open(file)
#       7     imgs.append(img)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py:3092, in open(fp, mode, formats)
#    3089     filename = fp
#    3091 if filename:
# -> 3092     fp = builtins.open(filename, "rb")
#    3093     exclusive_fp = True
#    3095 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'File_42.jpg'

# %%
imgs
# Out:
# []

# %%
from matplotlib.pyplot import show
from torchvision.transforms import transforms
import torch
from torchvision.utils import make_grid
import os
from PIL import Image

from torchvision.io import read_image
import matplotlib.pyplot as plt


import glob
cv_img_left = []
e = False
for img in glob.glob("/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/Projected-FastGan/dcgan_land/left/*.png"):
    n= Image.open(img)
    n = n.resize((16,16))
    transform = transforms.ToTensor()
    m = transform(n)
    cv_img_left.append(m)
    if len(cv_img_left) == 128:
        e = True
    if e is True:
        break
plt.figure(figsize=(10,10))
plt.title("Projected FastGan Samples- Left Images")
plt.imshow(make_grid(cv_img_left, nrow=4).permute(1, 2, 0))#, aspect="auto")

# %%
cv_img_right = []
e = False
for img in glob.glob("/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/Projected-FastGan/dcgan_land/right/*.png"):
    n= Image.open(img)
    n = n.resize((16,16), Image.ANTIALIAS)
    transform = transforms.ToTensor()
    m = transform(n)
    cv_img_right.append(m)
    if len(cv_img_right) == 128:
        e = True
    if e is True:
        break
plt.figure(figsize=(10,10))
plt.title("Projected FastGan Samples- Left Images")
plt.imshow(make_grid(cv_img_right, nrow=4).permute(1, 2, 0))#, aspect="auto")
# Out:
# /var/folders/10/mlk4wbh16ysgmbqf0q2dns700000gn/T/ipykernel_8204/2337887636.py:5: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   n = n.resize((16,16), Image.ANTIALIAS)

# %%
plt.figure(figsize=(10,10))


plt.subplot(1,2,1)
plt.imshow(make_grid(cv_img_left, nrow=4).permute(1, 2, 0))#, aspect="auto")
plt.title("DCGAN Landscape Left Images")
plt.subplot(1,2,2)
plt.imshow(make_grid(cv_img_right, nrow=4).permute(1,2,0))
plt.title("DCGAN Landscape Right Images")
plt.show()

# %%
import cv2

# %%
plt.figure(figsize=(8,8))

drive_left= Image.open("/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/drive_depth/left.png")
drive_right= Image.open("/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/drive_depth/right.png")
drive_depth= Image.open("/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/drive_depth/depth.png")

land_left= "/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/land_depth/left.png"
land_right= "/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/land_depth/right.png"
land_depth= "/Users/vignesh/Documents/GitHub/Msc-Project-2.5D-Image-Generation/land_depth/depth.png"

plt.subplot(1,3,1)
plt.imshow(drive_left)
plt.title("Left Generated Image")
plt.subplot(1,3,2)
plt.imshow(drive_right)
plt.title("Right Generated Image")
plt.subplot(1,3,3)
plt.imshow(drive_depth)
plt.title("Estimated Depth Map")
plt.subplots_adjust(wspace=0.3)
plt.show()
